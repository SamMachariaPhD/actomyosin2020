# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
va125 = pd.read_csv('dataDt/v11a1_25mtrs_std273s1.csv', names=['spec1','dev1','spec2','dev2'])
va25 = pd.read_csv('dataDt/v11a2_5mtrs_std273s1.csv', names=['spec1','dev1','spec2','dev2'])
va50 = pd.read_csv('dataDt/v11a5_0mtrs_std273s1.csv', names=['spec1','dev1','spec2','dev2'])
va75 = pd.read_csv('dataDt/v11a7_5mtrs_std273s1.csv', names=['spec1','dev1','spec2','dev2'])
va10 = pd.read_csv('dataDt/v11a10mtrs_std273s1.csv', names=['spec1','dev1','spec2','dev2'])

vh125 = pd.read_csv('dataDt/v11h1_25mtrs_std273s1.csv', names=['spec1','dev1','spec2','dev2'])
vh125_2 = pd.read_csv('dataDt/v11h1_25mtrs_std213s1.csv', names=['spec1','dev1','spec2','dev2'])
vh125_3 = pd.read_csv('dataDt/v11h1_25mtrs_std210s1.csv', names=['spec1','dev1','spec2','dev2'])

vh25 = pd.read_csv('dataDt/v11h2_5mtrs_std273s1.csv', names=['spec1','dev1','spec2','dev2'])
vh25_2 = pd.read_csv('dataDt/v11h2_5mtrs_std213s1.csv', names=['spec1','dev1','spec2','dev2'])
vh25_3 = pd.read_csv('dataDt/v11h2_5mtrs_std210s1.csv', names=['spec1','dev1','spec2','dev2'])

vh50 = pd.read_csv('dataDt/v11h5_0mtrs_std273s1.csv', names=['spec1','dev1','spec2','dev2'])
vh50_2 = pd.read_csv('dataDt/v11h5_0mtrs_std213s1.csv', names=['spec1','dev1','spec2','dev2'])
vh50_3 = pd.read_csv('dataDt/v11h5_0mtrs_std210s1.csv', names=['spec1','dev1','spec2','dev2'])

vh75 = pd.read_csv('dataDt/v11h7_5mtrs_std273s1.csv', names=['spec1','dev1','spec2','dev2'])
vh75_2 = pd.read_csv('dataDt/v11h7_5mtrs_std213s1.csv', names=['spec1','dev1','spec2','dev2'])
vh75_3 = pd.read_csv('dataDt/v11h7_5mtrs_std210s1.csv', names=['spec1','dev1','spec2','dev2'])

vh10 = pd.read_csv('dataDt/v11h10mtrs_std273s1.csv', names=['spec1','dev1','spec2','dev2'])

r = np.array([0.5,0.6,0.7,0.8,0.9,1.0])

# %%
fig, ax = plt.subplots(figsize=(10,8))
#plt.style.use('ggplot') # like R figures *

ax.errorbar(r,va25['spec1'],va25['dev1'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='red', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='V11a2.5')
ax.errorbar(r,va25['spec2'],va25['dev2'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='red', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')

ax.errorbar(r,vh25['spec1'],vh25['dev1'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='red', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='V11h2.5')
ax.errorbar(r,vh25['spec2'],vh25['dev2'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='red', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')
#=======
ax.errorbar(r,va50['spec1'],va50['dev1'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='green', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='V11a5.0')
ax.errorbar(r,va50['spec2'],va50['dev2'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='green', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')

ax.errorbar(r,vh50['spec1'],vh50['dev1'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='green', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='V11h5.0')
ax.errorbar(r,vh50['spec2'],vh50['dev2'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='green', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')
#=======
ax.errorbar(r,va75['spec1'],va75['dev1'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='blue', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='V11a7.5')
ax.errorbar(r,va75['spec2'],va75['dev2'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='blue', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')

ax.errorbar(r,vh75['spec1'],vh75['dev1'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='blue', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='V11h7.5')
ax.errorbar(r,vh75['spec2'],vh75['dev2'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='blue', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')
#=======
ax.errorbar(r,va10['spec1'],va10['dev1'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='black', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='V11a10')
ax.errorbar(r,va10['spec2'],va10['dev2'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='black', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')

ax.errorbar(r,vh10['spec1'],vh10['dev1'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='black', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='V11h10')
ax.errorbar(r,vh10['spec2'],vh10['dev2'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='black', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')


ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

ax.spines['bottom'].set_position(('axes',-0.01))
ax.spines['left'].set_position(('axes',-0.01))
ax.spines['left'].set_bounds(0,180)

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_xticks(np.arange(0,1.21,step=0.2))
ax.set_yticks(np.arange(0,181,20))
#ax.set_ylim(ymin=0)

ax.tick_params(labelsize=18, direction='out', length=6, width=1) # colors='r', grid_color='r', grid_alpha=0.5
ax.set_xlabel('Motor ratio', fontsize=18)
ax.set_ylabel('Mean binding motors', fontsize=18)
ax.legend(loc='upper left')

fig.tight_layout()
#plt.savefig('fig/v11a_hBindingMotorDtChanges.svg', fmt='svg', dip='1200', bbox_inches='tight')
#plt.savefig('fig/v11a_hBindingMotorDtChanges.png', fmt='png', dip='1200', bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,8))
#plt.style.use('ggplot') # like R figures *

ax.errorbar(r,va125['spec1'],va125['dev1'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='blue', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='V11a1.25')
ax.errorbar(r,va125['spec2'],va125['dev2'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='blue', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')

ax.errorbar(r,vh125['spec1'],vh125['dev1'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='blue', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='V11h1.25')
ax.errorbar(r,vh125['spec2'],vh125['dev2'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='blue', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')
#=======
ax.errorbar(r,va25['spec1'],va25['dev1'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='red', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='V11a2.5')
ax.errorbar(r,va25['spec2'],va25['dev2'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='red', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')

ax.errorbar(r,vh25['spec1'],vh25['dev1'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='red', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='V11h2.5')
ax.errorbar(r,vh25['spec2'],vh25['dev2'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='red', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')
#=======
ax.errorbar(r,va50['spec1'],va50['dev1'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='green', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='V11a5.0')
ax.errorbar(r,va50['spec2'],va50['dev2'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='green', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')

ax.errorbar(r,vh50['spec1'],vh50['dev1'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='green', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='V11h5.0')
ax.errorbar(r,vh50['spec2'],vh50['dev2'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='green', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')
#=======


ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

ax.spines['bottom'].set_position(('axes',-0.01))
ax.spines['left'].set_position(('axes',-0.01))
ax.spines['left'].set_bounds(0,220)

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_xticks(np.arange(0,1.21,step=0.2))
ax.set_yticks(np.arange(0,221,20))
#ax.set_ylim(ymin=0)

ax.tick_params(labelsize=18, direction='out', length=6, width=1) # colors='r', grid_color='r', grid_alpha=0.5
ax.set_xlabel('Motor ratio', fontsize=18)
ax.set_ylabel('Mean binding motors', fontsize=18)
ax.legend(loc='upper left')

fig.tight_layout()
#plt.savefig('fig/v11a_h125BindingMotorDtChanges.svg', fmt='svg', dip='1200', bbox_inches='tight')
#plt.savefig('fig/v11a_h125BindingMotorDtChanges.png', fmt='png', dip='1200', bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,8))
#plt.style.use('ggplot') # like R figures *

ax.errorbar(r,vh125['spec1'],vh125['dev1'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='magenta', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='V11h1.25')
ax.errorbar(r,vh125['spec2'],vh125['dev2'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='magenta', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')
ax.errorbar(r[3:5],vh125_2['spec1'],vh125_2['dev1'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='magenta', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='')
ax.errorbar(r[3:5],vh125_2['spec2'],vh125_2['dev2'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='magenta', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')
ax.errorbar(r[3:5],vh125_3['spec1'],vh125_3['dev1'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='magenta', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='')
ax.errorbar(r[3:5],vh125_3['spec2'],vh125_3['dev2'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='magenta', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')

# ax.errorbar(r,va25['spec1'],va25['dev1'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='red', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='V11a2.5')
# ax.errorbar(r,va25['spec2'],va25['dev2'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='red', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')
# ax.errorbar(r,va25_2['spec1'],va25_2['dev1'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='red', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='')
# ax.errorbar(r,va25_2['spec2'],va25_2['dev2'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='red', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')
# ax.errorbar(r,va25_3['spec1'],va25_3['dev1'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='red', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='')
# ax.errorbar(r,va25_3['spec2'],va25_3['dev2'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='red', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')


ax.errorbar(r,vh25['spec1'],vh25['dev1'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='red', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='V11h2.5')
ax.errorbar(r,vh25['spec2'],vh25['dev2'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='red', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')
ax.errorbar(r[3:5],vh25_2['spec1'],vh25_2['dev1'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='red', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='')
ax.errorbar(r[3:5],vh25_2['spec2'],vh25_2['dev2'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='red', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')
ax.errorbar(r[3:5],vh25_3['spec1'],vh25_3['dev1'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='red', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='')
ax.errorbar(r[3:5],vh25_3['spec2'],vh25_3['dev2'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='red', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')
#=======
# ax.errorbar(r,va50['spec1'],va50['dev1'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='green', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='V11a5.0')
# ax.errorbar(r,va50['spec2'],va50['dev2'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='green', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')
# ax.errorbar(r,va50_2['spec1'],va50_2['dev1'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='green', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='')
# ax.errorbar(r,va50_2['spec2'],va50_2['dev2'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='green', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')
# ax.errorbar(r,va50_3['spec1'],va50_3['dev1'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='green', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='')
# ax.errorbar(r,va50_3['spec2'],va50_3['dev2'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='green', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')

ax.errorbar(r,vh50['spec1'],vh50['dev1'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='green', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='V11h5.0')
ax.errorbar(r,vh50['spec2'],vh50['dev2'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='green', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')
ax.errorbar(r[3:5],vh50_2['spec1'],vh50_2['dev1'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='green', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='')
ax.errorbar(r[3:5],vh50_2['spec2'],vh50_2['dev2'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='green', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')
ax.errorbar(r[3:5],vh50_3['spec1'],vh50_3['dev1'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='green', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='')
ax.errorbar(r[3:5],vh50_3['spec2'],vh50_3['dev2'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='green', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')
#=======
# ax.errorbar(r,va75['spec1'],va75['dev1'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='blue', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='V11a7.5')
# ax.errorbar(r,va75['spec2'],va75['dev2'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='blue', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')
# ax.errorbar(r,va75_2['spec1'],va75_2['dev1'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='blue', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='')
# ax.errorbar(r,va75_2['spec2'],va75_2['dev2'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='blue', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')
# ax.errorbar(r,va75_3['spec1'],va75_3['dev1'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='blue', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='')
# ax.errorbar(r,va75_3['spec2'],va75_3['dev2'], capsize=3, linestyle='--', linewidth=2, elinewidth=1, color='blue', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')

ax.errorbar(r,vh75['spec1'],vh75['dev1'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='blue', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='V11h7.5')
ax.errorbar(r,vh75['spec2'],vh75['dev2'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='blue', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')
ax.errorbar(r[3:5],vh75_2['spec1'],vh75_2['dev1'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='blue', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='')
ax.errorbar(r[3:5],vh75_2['spec2'],vh75_2['dev2'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='blue', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')
ax.errorbar(r[3:5],vh75_3['spec1'],vh75_3['dev1'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='blue', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='')
ax.errorbar(r[3:5],vh75_3['spec2'],vh75_3['dev2'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='blue', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')
#=======
ax.errorbar(r,vh10['spec1'],vh10['dev1'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='black', marker='o', markersize=8, markerfacecolor='none', ecolor='green', label='V11h10')
ax.errorbar(r,vh10['spec2'],vh10['dev2'], capsize=3, linestyle='-', linewidth=2, elinewidth=1, color='black', marker='o', markersize=8, markerfacecolor='none', ecolor='blue', label='')




ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

ax.spines['bottom'].set_position(('axes',-0.01))
ax.spines['left'].set_position(('axes',-0.01))
ax.spines['left'].set_bounds(0,240)

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_xticks(np.arange(0,1.21,step=0.2))
ax.set_yticks(np.arange(0,241,20))
#ax.set_ylim(ymin=0)

ax.tick_params(labelsize=18, direction='out', length=6, width=1) # colors='r', grid_color='r', grid_alpha=0.5
ax.set_xlabel('Motor ratio', fontsize=18)
ax.set_ylabel('Mean binding motors', fontsize=18)
ax.legend(loc='upper left')

fig.tight_layout()
#plt.savefig('fig/v11hBindingMotorDtChanges.svg', fmt='svg', dip='1200', bbox_inches='tight')
#plt.savefig('fig/v11hBindingMotorDtChanges.png', fmt='png', dip='1200', bbox_inches='tight')
plt.show()

# %%
gam = 3*np.pi*0.001*(0.25/(np.log(0.25/0.006)))
gam
# Out:
# 0.0006317380955666515

# %%
0.0041/gam
# Out:
# 6.490031278424668

# %%
bond_length = 0.25 #um
w_visc = 0.001
af_dia = 0.006
kbt = 0.0041
k = 300
fmax = 9.2

# %%
gamma = 3*np.pi*w_visc*(bond_length/np.log(bond_length/af_dia))

# %%
D = kbt/gamma
D
# Out:
# 6.490031278424668

# %%
# k * sqrt(2*D*Dt) = fmax

(fmax**2)/(2*D*k**2)
# Out:
# 7.245299784385009e-05

# %%
2**2
# Out:
# 4

# %% [markdown]
# `
# Date:       01-11-2020
# Params:      R0.5-1.0B13ATP2000MD2000S273T5.0
# About:       Actin-myosin conformation
# Version:     v11a*
# Data source: /media/nitta/HDCZ-UT1/NITTA-LAB HD2/Sam
# By:          Sam Macharia
# `

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mt1x = []; mt2x = []

for i in np.arange(0.1,1.1,0.1):
    mt1x_ = pd.read_csv('data3/MS1_no_113R'+str(round(i,1))+'.csv', names=['m'])
    mt1x.append(mt1x_)
    mt2x_ = pd.read_csv('data3/MS2_no_113R'+str(round(i,1))+'.csv', names=['m'])
    mt2x.append(mt2x_)

# %%
f = []; m1 = []; m2 = []; mt1 = []; mt2 = []

for i in range(501):
    f_ = pd.read_csv('data2/Filament_113R0.8Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    f.append(f_)
    m1_ = pd.read_csv('data2/Specie1_113R0.8Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    m1.append(m1_)
    m2_ = pd.read_csv('data2/Specie2_113R0.8Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    m2.append(m2_)
    mt1_ = pd.read_csv('data2/MotorSpecie1_113R0.8Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    mt1.append(mt1_)
    mt2_ = pd.read_csv('data2/MotorSpecie2_113R0.8Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    mt2.append(mt2_)

# %%
f05 = []; m105 = []; m205 = []; mt105 = []; mt205 = []

for i in range(501):
    f_ = pd.read_csv('data2/Filament_113R0.5Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    f05.append(f_)
    m1_ = pd.read_csv('data2/Specie1_113R0.5Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    m105.append(m1_)
    m2_ = pd.read_csv('data2/Specie2_113R0.5Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    m205.append(m2_)
    mt1_ = pd.read_csv('data2/MotorSpecie1_113R0.5Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    mt105.append(mt1_)
    mt2_ = pd.read_csv('data2/MotorSpecie2_113R0.5Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    mt205.append(mt2_)

# %%
f10 = []; m110 = []; m210 = []; mt110 = []; mt210 = []

for i in range(501):
    f_ = pd.read_csv('data2/Filament_113R1.0Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    f10.append(f_)
    m1_ = pd.read_csv('data2/Specie1_113R1.0Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    m110.append(m1_)
    m2_ = pd.read_csv('data2/Specie2_113R1.0Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    m210.append(m2_)
    mt1_ = pd.read_csv('data2/MotorSpecie1_113R1.0Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    mt110.append(mt1_)
    mt2_ = pd.read_csv('data2/MotorSpecie2_113R1.0Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    mt210.append(mt2_)

# %%
plt.figure(figsize=(15,5))
plt.style.use('ggplot')
plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)

count = 1
r = 0.8

for j in np.arange(50,501,50):
    #print('Plot %s, TimeStep %s'%(count,j))
    plt.subplot(2,5,count)
    plt.plot(f[j]['x'],f[j]['y'], linestyle='-', linewidth=2,\
         color='red', label='Actin filament')#, marker='o', markerfacecolor='none')
    plt.scatter(f[j]['x'][0],f[j]['y'][0], marker='D', color='black', label='Actin leading tip')
    plt.scatter(m1[j]['x'], m1[j]['y'], marker='o', s=20, color='green', label='Active myosin')
    plt.scatter(m2[j]['x'], m2[j]['y'], marker='o', s=20, color='blue', label='Inactive myosin')
    
    plt.title('R = %s, Ts = %s'%(r,j))
    plt.xticks(np.arange(1,6,1))
    plt.yticks(np.arange(-3,2,1))
    if count == 1:
        plt.ylabel('Y', fontsize=15)
    if count == 6:
        plt.ylabel('Y', fontsize=15)
    if count > 5:
        plt.xlabel('X', fontsize=15)
    count+=1
    #r=round((r+0.1),1)

#plt.savefig('fig/in_ac_bm.svg', fmt='.svg', dpi=1200, bbox_inches='tight')
#plt.savefig('fig/in_ac_bm.png', fmt='.png', dpi=1200, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)
plt.style.use('ggplot')
jmp = 30

count = 1
r = 0.8

for j in np.arange(50,501,50):
    #print('Plot %s, TimeStep %s'%(count,j))
    plt.subplot(2,5,count)
    plt.scatter(mt2[j].iloc[0::jmp,:]['x'], mt2[j].iloc[0::jmp,:]['y'], marker='o', s=15, color='blue', alpha=0.3, label='Inactive myosin')
    plt.scatter(mt1[j].iloc[0::jmp,:]['x'], mt1[j].iloc[0::jmp,:]['y'], marker='o', s=15, color='green', alpha=0.3, label='Active myosin')
    plt.plot(f[j]['x'],f[j]['y'], marker=None, markerfacecolor='none', linestyle='-', linewidth=4,\
         color='red', alpha=1, label='Actin filament')
    plt.scatter(f[j]['x'][0],f[j]['y'][0], marker='D', color='black', label='Actin leading tip')
    
    plt.title('R = %s, Ts = %s'%(r,j))
    plt.xticks(np.arange(0,9,2))
    plt.yticks(np.arange(-6,4,2))
    if count == 1:
        plt.ylabel('Y', fontsize=15)
    if count == 6:
        plt.ylabel('Y', fontsize=15)
    if count > 5:
        plt.xlabel('X', fontsize=15)
    count+=1
    #r=round((r+0.1),1)

#plt.savefig('fig/ts_conformation.svg', fmt='.svg', dpi=1200, bbox_inches='tight')
#plt.savefig('fig/ts_conformation.png', fmt='.png', dpi=1200, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.subplots_adjust(wspace=0.7)
plt.subplots_adjust(hspace=0.25)
plt.style.use('ggplot')

jmp = 30

plt.subplot(331)
plt.scatter(mt205[50].iloc[0::jmp,:]['x'], mt205[50].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightblue', alpha=1)
plt.scatter(mt105[50].iloc[0::jmp,:]['x'], mt105[50].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightgreen', alpha=1)

plt.scatter(mt205[250].iloc[0::jmp,:]['x'], mt205[250].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightblue', alpha=1)
plt.scatter(mt105[250].iloc[0::jmp,:]['x'], mt105[250].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightgreen', alpha=1)

plt.scatter(mt205[500].iloc[0::jmp,:]['x'], mt205[500].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightblue', alpha=1)
plt.scatter(mt105[500].iloc[0::jmp,:]['x'], mt105[500].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightgreen', alpha=1)

plt.plot(f05[50]['x'],f05[50]['y'], marker=None, markerfacecolor='none', linestyle='-', linewidth=4,\
         color='red', alpha=1, label='Actin filament')
plt.scatter(f05[50]['x'][0],f05[50]['y'][0], marker='D', color='black', label='Actin leading tip')

plt.xticks(np.arange(-4,14,4))
plt.yticks(np.arange(-22,10,6))

plt.title('R = 0.5', fontsize=16) # , 0.5 sec.
plt.ylabel('Y ($\mu m$)', fontsize=15)
#======================================================
plt.subplot(334)
plt.scatter(mt205[50].iloc[0::jmp,:]['x'], mt205[50].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightblue', alpha=1)
plt.scatter(mt105[50].iloc[0::jmp,:]['x'], mt105[50].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightgreen', alpha=1)

plt.scatter(mt205[250].iloc[0::jmp,:]['x'], mt205[250].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightblue', alpha=1)
plt.scatter(mt105[250].iloc[0::jmp,:]['x'], mt105[250].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightgreen', alpha=1)

plt.scatter(mt205[500].iloc[0::jmp,:]['x'], mt205[500].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightblue', alpha=1)
plt.scatter(mt105[500].iloc[0::jmp,:]['x'], mt105[500].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightgreen', alpha=1)

plt.plot(f05[250]['x'],f05[250]['y'], marker=None, markerfacecolor='none', linestyle='-', linewidth=4,\
         color='red', alpha=1, label='Actin filament')
plt.scatter(f05[250]['x'][0],f05[250]['y'][0], marker='D', color='black')

plt.xticks(np.arange(-4,14,4))
plt.yticks(np.arange(-22,10,6))
plt.ylabel('Y ($\mu m$)', fontsize=15)

#plt.title('R = 0.5, Ts = 250', fontsize=16)
#========================================================
plt.subplot(337)
plt.scatter(mt205[50].iloc[0::jmp,:]['x'], mt205[50].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightblue', alpha=1)
plt.scatter(mt105[50].iloc[0::jmp,:]['x'], mt105[50].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightgreen', alpha=1)

plt.scatter(mt205[250].iloc[0::jmp,:]['x'], mt205[250].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightblue', alpha=1)
plt.scatter(mt105[250].iloc[0::jmp,:]['x'], mt105[250].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightgreen', alpha=1)

plt.scatter(mt205[500].iloc[0::jmp,:]['x'], mt205[500].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightblue', alpha=1)
plt.scatter(mt105[500].iloc[0::jmp,:]['x'], mt105[500].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightgreen', alpha=1)

plt.plot(f05[500]['x'],f05[500]['y'], marker=None, markerfacecolor='none', linestyle='-', linewidth=4,\
         color='red', alpha=1, label='Actin filament')
plt.scatter(f05[500]['x'][0],f05[500]['y'][0], marker='D', color='black')

#plt.title('R = 0.5, Ts = 500', fontsize=16)
plt.xticks(np.arange(-4,14,4))
plt.yticks(np.arange(-22,10,6))
plt.xlabel('X ($\mu m$)', fontsize=15)
plt.ylabel('Y ($\mu m$)', fontsize=15)

#==========================================================================

plt.subplot(332)
plt.scatter(mt2[50].iloc[0::jmp,:]['x'], mt2[50].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightblue', alpha=1)
plt.scatter(mt1[50].iloc[0::jmp,:]['x'], mt1[50].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightgreen', alpha=1)

plt.scatter(mt2[250].iloc[0::jmp,:]['x'], mt2[250].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightblue', alpha=1)
plt.scatter(mt1[250].iloc[0::jmp,:]['x'], mt1[250].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightgreen', alpha=1)

plt.scatter(mt2[500].iloc[0::jmp,:]['x'], mt2[500].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightblue', alpha=1)
plt.scatter(mt1[500].iloc[0::jmp,:]['x'], mt1[500].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightgreen', alpha=1)

plt.plot(f[50]['x'],f[50]['y'], marker=None, markerfacecolor='none', linestyle='-', linewidth=4,\
         color='red', alpha=1, label='Actin filament')
plt.scatter(f[50]['x'][0],f[50]['y'][0], marker='D', color='black', label='Actin leading tip')

plt.xticks(np.arange(-4,14,4))
plt.yticks(np.arange(-22,10,6))

plt.title('R = 0.8', fontsize=16) # , 2.5 sec.

#============================================================
plt.subplot(335)
plt.scatter(mt2[50].iloc[0::jmp,:]['x'], mt2[50].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightblue', alpha=1)
plt.scatter(mt1[50].iloc[0::jmp,:]['x'], mt1[50].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightgreen', alpha=1)

plt.scatter(mt2[250].iloc[0::jmp,:]['x'], mt2[250].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightblue', alpha=1)
plt.scatter(mt1[250].iloc[0::jmp,:]['x'], mt1[250].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightgreen', alpha=1)

plt.scatter(mt2[500].iloc[0::jmp,:]['x'], mt2[500].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightblue', alpha=1)
plt.scatter(mt1[500].iloc[0::jmp,:]['x'], mt1[500].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightgreen', alpha=1)

plt.plot(f[250]['x'],f[250]['y'], marker=None, markerfacecolor='none', linestyle='-', linewidth=4,\
         color='red', alpha=1, label='Actin filament')
plt.scatter(f[250]['x'][0],f[250]['y'][0], marker='D', color='black')

#plt.title('R = 0.8, Ts = 250', fontsize=16)
plt.xticks(np.arange(-4,14,4))
plt.yticks(np.arange(-22,10,6))
#plt.ylabel('Y ($\mu m$)', fontsize=15)
#=============================================================
plt.subplot(338)
plt.scatter(mt2[50].iloc[0::jmp,:]['x'], mt2[50].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightblue', alpha=1)
plt.scatter(mt1[50].iloc[0::jmp,:]['x'], mt1[50].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightgreen', alpha=1)

plt.scatter(mt2[250].iloc[0::jmp,:]['x'], mt2[250].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightblue', alpha=1)
plt.scatter(mt1[250].iloc[0::jmp,:]['x'], mt1[250].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightgreen', alpha=1)

plt.scatter(mt2[500].iloc[0::jmp,:]['x'], mt2[500].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightblue', alpha=1)
plt.scatter(mt1[500].iloc[0::jmp,:]['x'], mt1[500].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightgreen', alpha=1)

plt.plot(f[500]['x'],f[500]['y'], marker=None, markerfacecolor='none', linestyle='-', linewidth=4,\
         color='red', alpha=1, label='Actin filament')
plt.scatter(f[500]['x'][0],f[500]['y'][0], marker='D', color='black')

#plt.title('R = 0.8, Ts = 500', fontsize=16)
plt.xticks(np.arange(-4,14,4))
plt.yticks(np.arange(-22,10,6))

plt.xlabel('X ($\mu m$)', fontsize=15)

#====================================================================================

plt.subplot(333)
for i in np.arange(50,501,50):
    plt.scatter(mt210[i].iloc[0::jmp,:]['x'], mt210[i].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightblue', alpha=1)
    plt.scatter(mt110[i].iloc[0::jmp,:]['x'], mt110[i].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightgreen', alpha=1)

plt.plot(f10[50]['x'],f10[50]['y'], marker=None, markerfacecolor='none', linestyle='-', linewidth=4,\
         color='red', alpha=1, label='Actin filament')
plt.scatter(f10[50]['x'][0],f10[50]['y'][0], marker='D', color='black', label='Actin leading tip')

plt.xticks(np.arange(-4,14,4))
plt.yticks(np.arange(-22,10,6))

plt.title('R = 1.0', fontsize=16) # , 5 sec.
#plt.ylabel('Y ($\mu m$)', fontsize=15)
#plt.xlabel('X ($\mu m$)', fontsize=15)
#================================================================
plt.subplot(336)
for i in np.arange(50,501,50):
    plt.scatter(mt210[i].iloc[0::jmp,:]['x'], mt210[i].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightblue', alpha=1)
    plt.scatter(mt110[i].iloc[0::jmp,:]['x'], mt110[i].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightgreen', alpha=1)

plt.plot(f10[250]['x'],f10[250]['y'], marker=None, markerfacecolor='none', linestyle='-', linewidth=4,\
         color='red', alpha=1, label='Actin filament')
plt.scatter(f10[250]['x'][0],f10[250]['y'][0], marker='D', color='black')

plt.xticks(np.arange(-4,14,4))
plt.yticks(np.arange(-22,10,6))

#plt.title('R = 1.0, Ts = 250', fontsize=16)
#plt.ylabel('Y ($\mu m$)', fontsize=15)
#plt.xlabel('X ($\mu m$)', fontsize=15)
#===============================================================
plt.subplot(339)
for i in np.arange(50,501,50):
    plt.scatter(mt210[i].iloc[0::jmp,:]['x'], mt210[i].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightblue', alpha=1)
    plt.scatter(mt110[i].iloc[0::jmp,:]['x'], mt110[i].iloc[0::jmp,:]['y'], marker='o', s=15, color='lightgreen', alpha=1)

plt.plot(f10[500]['x'],f10[500]['y'], marker=None, markerfacecolor='none', linestyle='-', linewidth=4,\
         color='red', alpha=1, label='Actin filament')
plt.scatter(f10[500]['x'][0],f10[500]['y'][0], marker='D', color='black')

plt.xticks(np.arange(-4,14,4))
plt.yticks(np.arange(-22,10,6))

#plt.title('R = 1.0, Ts = 500', fontsize=16)
plt.xlabel('X ($\mu m$)', fontsize=15)

#plt.savefig('fig/ts_conformationPsta.png', fmt='.png', dpi=1500, bbox_inches='tight')

plt.show()

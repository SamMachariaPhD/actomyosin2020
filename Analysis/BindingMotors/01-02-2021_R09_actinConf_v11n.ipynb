# %% [markdown]
# `
# Date:       01-02-2021
# Params:      R0.9-0.98B13ATP2000MD2000S273T5.0
# About:       Actin conformation
# Version:     v11n
# Data source: /media/nitta/HDCZ-UT/NITTA-LAB HD3/Sam/V11n/dt1.0s5/SEED273MD2000
# By:          Sam Macharia
# `

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
# %matplotlib inline

# %%
f = []; m1 = []; m2 = []; mt1 = []; mt2 = []

for i in range(501):
    f_ = pd.read_csv('data4dt1/Filament_5s273R0.9Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    f.append(f_)
    m1_ = pd.read_csv('data4dt1/Specie1_5s273R0.9Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    m1.append(m1_)
    m2_ = pd.read_csv('data4dt1/Specie2_5s273R0.9Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    m2.append(m2_)
    mt1_ = pd.read_csv('data4dt1/MotorSpecie1_5s273R0.9Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    mt1.append(mt1_)
    mt2_ = pd.read_csv('data4dt1/MotorSpecie2_5s273R0.9Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    mt2.append(mt2_)

# %%
f05 = []; m105 = []; m205 = []; mt105 = []; mt205 = []

for i in range(501):
    f_ = pd.read_csv('data4dt1/Filament_5s273R0.92Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    f05.append(f_)
    m1_ = pd.read_csv('data4dt1/Specie1_5s273R0.92Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    m105.append(m1_)
    m2_ = pd.read_csv('data4dt1/Specie2_5s273R0.92Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    m205.append(m2_)
    mt1_ = pd.read_csv('data4dt1/MotorSpecie1_5s273R0.92Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    mt105.append(mt1_)
    mt2_ = pd.read_csv('data4dt1/MotorSpecie2_5s273R0.92Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    mt205.append(mt2_)

# %%
f10 = []; m110 = []; m210 = []; mt110 = []; mt210 = []

for i in range(501):
    f_ = pd.read_csv('data4dt1/Filament_5s273R0.98Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    f10.append(f_)
    m1_ = pd.read_csv('data4dt1/Specie1_5s273R0.98Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    m110.append(m1_)
    m2_ = pd.read_csv('data4dt1/Specie2_5s273R0.98Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    m210.append(m2_)
    mt1_ = pd.read_csv('data4dt1/MotorSpecie1_5s273R0.98Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    mt110.append(mt1_)
    mt2_ = pd.read_csv('data4dt1/MotorSpecie2_5s273R0.98Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1)
    mt210.append(mt2_)

# %%
plt.figure(figsize=(14,8))
plt.subplots_adjust(wspace=0.25)
plt.subplots_adjust(hspace=0.2)
plt.style.use('ggplot')
#plt.axes().set_aspect('equal')

jmp = 50
fnt = 28
alp = 0.3

plt.subplot(331)
fts = 0
for i in np.arange(0,501,50):
    plt.scatter(mt1[i].iloc[0::jmp,:]['x'], mt1[i].iloc[0::jmp,:]['y'], marker='.', s=3, color='green', alpha=alp)
    plt.scatter(mt2[i].iloc[0::jmp,:]['x'], mt2[i].iloc[0::jmp,:]['y'], marker='.', s=3, color='blue', alpha=alp)

plt.plot(f[fts]['x'],f[fts]['y'], marker=None, markerfacecolor='none', linestyle='-', linewidth=3,\
         color='red', alpha=1, path_effects=[pe.Stroke(linewidth=5,foreground='white'),pe.Normal()])

plt.xticks(np.arange(-0,29,7))
plt.yticks(np.arange(-2,15,7))
plt.tick_params(labelsize=18)
plt.tick_params(axis='x', bottom=False, which='both', labelbottom=False)

plt.title('R = 0.9', fontsize=fnt) # , 0.5 sec.
#plt.ylabel('Y ($\mu m$)', fontsize=28)
#======================================================
plt.subplot(334)
fts = 250
for i in np.arange(0,501,50):
    plt.scatter(mt1[i].iloc[0::jmp,:]['x'], mt1[i].iloc[0::jmp,:]['y'], marker='.', s=3, color='green', alpha=alp)
    plt.scatter(mt2[i].iloc[0::jmp,:]['x'], mt2[i].iloc[0::jmp,:]['y'], marker='.', s=3, color='blue', alpha=alp)

plt.plot(f[fts]['x'],f[fts]['y'], marker=None, markerfacecolor='none', linestyle='-', linewidth=3,\
         color='red', alpha=1, path_effects=[pe.Stroke(linewidth=5,foreground='white'),pe.Normal()])

plt.xticks(np.arange(-0,29,7))
plt.yticks(np.arange(-2,15,7))
plt.tick_params(labelsize=18)
plt.tick_params(axis='x', bottom=False, which='both', labelbottom=False)

plt.ylabel('Y ($\mu m$)', fontsize=fnt)

#========================================================
plt.subplot(337)
fts = 500
for i in np.arange(0,501,50):
    plt.scatter(mt1[i].iloc[0::jmp,:]['x'], mt1[i].iloc[0::jmp,:]['y'], marker='.', s=3, color='green', alpha=alp)
    plt.scatter(mt2[i].iloc[0::jmp,:]['x'], mt2[i].iloc[0::jmp,:]['y'], marker='.', s=3, color='blue', alpha=alp)

plt.plot(f[fts]['x'],f[fts]['y'], marker=None, markerfacecolor='none', linestyle='-', linewidth=3,\
         color='red', alpha=1, path_effects=[pe.Stroke(linewidth=5,foreground='white'),pe.Normal()])

plt.xticks(np.arange(-0,29,7))
plt.yticks(np.arange(-2,15,7))
plt.tick_params(labelsize=18)

#plt.xlabel('X ($\mu m$)', fontsize=28)
#plt.ylabel('Y ($\mu m$)', fontsize=28)

#==========================================================================

plt.subplot(332)
fts = 0
for i in np.arange(0,501,50):
    plt.scatter(mt105[i].iloc[0::jmp,:]['x'], mt105[i].iloc[0::jmp,:]['y'], marker='.', s=3, color='green', alpha=alp)
    plt.scatter(mt205[i].iloc[0::jmp,:]['x'], mt205[i].iloc[0::jmp,:]['y'], marker='.', s=3, color='blue', alpha=alp)

plt.plot(f05[fts]['x'],f05[fts]['y'], marker=None, markerfacecolor='none', linestyle='-', linewidth=3,\
         color='red', alpha=1, path_effects=[pe.Stroke(linewidth=5,foreground='white'),pe.Normal()])

plt.xticks(np.arange(-0,29,7))
plt.yticks(np.arange(-2,15,7))
plt.tick_params(labelsize=18)
plt.tick_params(axis='y', left=False, which='both', labelleft=False)
plt.tick_params(axis='x', bottom=False, which='both', labelbottom=False)

plt.title('R = 0.92', fontsize=fnt) # , 2.5 sec.

#============================================================
plt.subplot(335)
fts = 250
for i in np.arange(0,501,50):
    plt.scatter(mt105[i].iloc[0::jmp,:]['x'], mt105[i].iloc[0::jmp,:]['y'], marker='.', s=3, color='green', alpha=alp)
    plt.scatter(mt205[i].iloc[0::jmp,:]['x'], mt205[i].iloc[0::jmp,:]['y'], marker='.', s=3, color='blue', alpha=alp)

plt.plot(f05[fts]['x'],f05[fts]['y'], marker=None, markerfacecolor='none', linestyle='-', linewidth=3,\
         color='red', alpha=1, path_effects=[pe.Stroke(linewidth=5,foreground='white'),pe.Normal()])


plt.xticks(np.arange(-0,29,7))
plt.yticks(np.arange(-2,15,7))
plt.tick_params(labelsize=18)
plt.tick_params(axis='y', left=False, which='both', labelleft=False)
plt.tick_params(axis='x', bottom=False, which='both', labelbottom=False)

#=============================================================
plt.subplot(338)
fts = 500
for i in np.arange(0,501,50):
    plt.scatter(mt105[i].iloc[0::jmp,:]['x'], mt105[i].iloc[0::jmp,:]['y'], marker='.', s=3, color='green', alpha=alp)
    plt.scatter(mt205[i].iloc[0::jmp,:]['x'], mt205[i].iloc[0::jmp,:]['y'], marker='.', s=3, color='blue', alpha=alp)

plt.plot(f05[fts]['x'],f05[fts]['y'], marker=None, markerfacecolor='none', linestyle='-', linewidth=3,\
         color='red', path_effects=[pe.Stroke(linewidth=5,foreground='white'),pe.Normal()])

plt.xticks(np.arange(-0,29,7))
plt.yticks(np.arange(-2,15,7))
plt.tick_params(labelsize=18)
plt.tick_params(axis='y', left=False, which='both', labelleft=False)

plt.xlabel('X ($\mu m$)', fontsize=fnt)

#====================================================================================

plt.subplot(333)
fts = 0
for i in np.arange(0,501,50):
    plt.scatter(mt110[i].iloc[0::jmp,:]['x'], mt110[i].iloc[0::jmp,:]['y'], marker='.', s=3, color='green', alpha=alp)
    plt.scatter(mt210[i].iloc[0::jmp,:]['x'], mt210[i].iloc[0::jmp,:]['y'], marker='.', s=3, color='blue', alpha=alp)

plt.plot(f10[fts]['x'],f10[fts]['y'], marker=None, markerfacecolor='none', linestyle='-', linewidth=3,\
         color='red', alpha=1, path_effects=[pe.Stroke(linewidth=5,foreground='white'),pe.Normal()])

plt.xticks(np.arange(-0,29,7))
plt.yticks(np.arange(-2,15,7))
plt.tick_params(labelsize=18)
plt.tick_params(axis='y', left=False, which='both', labelleft=False)
plt.tick_params(axis='x', bottom=False, which='both', labelbottom=False)

plt.title('R = 0.98', fontsize=fnt) # , 0 sec.

plt.ylabel('0.0 sec.', labelpad=-260, fontsize=fnt)

#================================================================
plt.subplot(336)
fts = 250
for i in np.arange(0,501,50):
    plt.scatter(mt110[i].iloc[0::jmp,:]['x'], mt110[i].iloc[0::jmp,:]['y'], marker='.', s=3, color='green', alpha=alp)
    plt.scatter(mt210[i].iloc[0::jmp,:]['x'], mt210[i].iloc[0::jmp,:]['y'], marker='.', s=3, color='blue', alpha=alp)

plt.plot(f10[fts]['x'],f10[fts]['y'], marker=None, markerfacecolor='none', linestyle='-', linewidth=3,\
         color='red', alpha=1, path_effects=[pe.Stroke(linewidth=5,foreground='white'),pe.Normal()])

plt.xticks(np.arange(-0,29,7))
plt.yticks(np.arange(-2,15,7))
plt.tick_params(labelsize=18)
plt.tick_params(axis='y', left=False, which='both', labelleft=False)
plt.tick_params(axis='x', bottom=False, which='both', labelbottom=False)

plt.ylabel('2.5 sec.', labelpad=-260, fontsize=fnt)

#===============================================================
plt.subplot(339)
fts = 500
for i in np.arange(0,501,50):
    plt.scatter(mt110[i].iloc[0::jmp,:]['x'], mt110[i].iloc[0::jmp,:]['y'], marker='.', s=3, color='green', alpha=alp)
    plt.scatter(mt210[i].iloc[0::jmp,:]['x'], mt210[i].iloc[0::jmp,:]['y'], marker='.', s=3, color='blue', alpha=alp)

plt.plot(f10[fts]['x'],f10[fts]['y'], marker=None, markerfacecolor='none', linestyle='-', linewidth=3,\
         color='red', alpha=1, path_effects=[pe.Stroke(linewidth=5,foreground='white'),pe.Normal()])
#plt.scatter(f10[500]['x'][0],f10[500]['y'][0], marker='D', color='black')

plt.xticks(np.arange(-0,29,7))
plt.yticks(np.arange(-2,15,7))
plt.tick_params(labelsize=18)
plt.tick_params(axis='y', left=False, which='both', labelleft=False)

plt.ylabel('5.0 sec.', labelpad=-260, fontsize=fnt)

#plt.xlabel('X ($\mu m$)', fontsize=28)

#plt.savefig('fig/afMyosinInteraction_R09_098s5dt01.png', format='png', dpi=700, bbox_inches='tight')
#plt.savefig('fig/afMyosinInteraction_R09_098s5dt01.pdf', format='pdf', dpi=100, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(14,2))
plt.subplots_adjust(wspace=0.25)
plt.subplots_adjust(hspace=0.2)
plt.style.use('ggplot')
#plt.axes().set_aspect('equal')

jmp1 = 5; jmp2 = 10
fnt = 16
alp = 0.3

plt.subplot(141)
fts = 120; ts = 180
plt.scatter(mt105[ts].iloc[0::jmp1,:]['x'], mt105[ts].iloc[0::jmp1,:]['y'], marker='o',facecolor='green', s=3, color='green', alpha=alp)
plt.scatter(mt205[ts].iloc[0::jmp2,:]['x'], mt205[ts].iloc[0::jmp2,:]['y'], marker='o',facecolor='blue', s=3, color='blue', alpha=alp)
# plt.plot(f05[fts]['x'],f05[fts]['y'], marker=None, markerfacecolor='none', linestyle='-', linewidth=5,\
#          color='white', alpha=1, label='Actin filament')
plt.plot(f05[fts]['x'],f05[fts]['y'], marker=None, markerfacecolor='none', linestyle='-', linewidth=3,\
         color='red', alpha=1, path_effects=[pe.Stroke(linewidth=5,foreground='white'),pe.Normal()])
plt.xlabel('(a) 1.2 sec.', fontsize=fnt)
#======================================================
plt.subplot(142)
fts = 140; ts = 180
plt.scatter(mt105[ts].iloc[0::jmp1,:]['x'], mt105[ts].iloc[0::jmp1,:]['y'], marker='o',facecolor='green', s=3, color='green', alpha=alp)
plt.scatter(mt205[ts].iloc[0::jmp2,:]['x'], mt205[ts].iloc[0::jmp2,:]['y'], marker='o',facecolor='blue', s=3, color='blue', alpha=alp)
plt.plot(f05[fts]['x'],f05[fts]['y'], marker=None, markerfacecolor='none', linestyle='-', linewidth=3,\
         color='red', alpha=1, path_effects=[pe.Stroke(linewidth=5,foreground='white'),pe.Normal()])
plt.xlabel('(b) 1.4 sec.', fontsize=fnt)
#========================================================
plt.subplot(143)
fts = 160; ts = 180
plt.scatter(mt105[ts].iloc[0::jmp1,:]['x'], mt105[ts].iloc[0::jmp1,:]['y'], marker='o',facecolor='green', s=3, color='green', alpha=alp)
plt.scatter(mt205[ts].iloc[0::jmp2,:]['x'], mt205[ts].iloc[0::jmp2,:]['y'], marker='o',facecolor='blue', s=3, color='blue', alpha=alp)
plt.plot(f05[fts]['x'],f05[fts]['y'], marker=None, markerfacecolor='none', linestyle='-', linewidth=3,\
         color='red', alpha=1, path_effects=[pe.Stroke(linewidth=5,foreground='white'),pe.Normal()])
plt.xlabel('(c) 1.6 sec.', fontsize=fnt)
#==========================================================================

plt.subplot(144)
fts = 180; ts = 180
plt.scatter(mt105[ts].iloc[0::jmp1,:]['x'], mt105[ts].iloc[0::jmp1,:]['y'], marker='o',facecolor='green', s=3, color='green', alpha=alp)
plt.scatter(mt205[ts].iloc[0::jmp2,:]['x'], mt205[ts].iloc[0::jmp2,:]['y'], marker='o',facecolor='blue', s=3, color='blue', alpha=alp)
plt.plot(f05[fts]['x'],f05[fts]['y'], marker=None, markerfacecolor='none', linestyle='-', linewidth=3,\
         color='red', alpha=1, path_effects=[pe.Stroke(linewidth=5,foreground='white'),pe.Normal()])

#plt.title('R = 0.92', fontsize=28) # , 2.5 sec.
plt.xlabel('(d) 1.8 sec.', fontsize=fnt)
#plt.savefig('fig/transitionMoves_R092s5dt01.pdf', format='pdf', dpi=700, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-cbe41fd8e58c> in <module>
# ----> 1 plt.figure(figsize=(14,2))
#       2 plt.subplots_adjust(wspace=0.25)
#       3 plt.subplots_adjust(hspace=0.2)
#       4 plt.style.use('ggplot')
#       5 #plt.axes().set_aspect('equal')
#
# NameError: name 'plt' is not defined

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# jupyter nbconvert xxx.ipynb --no-input

# %%
r03dt2ac = pd.read_csv('data/acBmR03dt2.csv', names=['bm'])
r03dt2def = pd.read_csv('data/defBmR03dt2.csv', names=['bm'])
r09dt2ac = pd.read_csv('data/acBmR09dt2.csv', names=['bm'])
r09dt2def = pd.read_csv('data/defBmR09dt2.csv', names=['bm'])

r03dt5k30ac = pd.read_csv('data/acBmR03dt5k30.csv', names=['bm'])
r03dt5k30def = pd.read_csv('data/defBmR03dt5k30.csv', names=['bm'])
r09dt5k30ac = pd.read_csv('data/acBmR09dt5k30.csv', names=['bm'])
r09dt5k30def = pd.read_csv('data/defBmR09dt5k30.csv', names=['bm'])
r03dt5k30 = pd.read_csv('data/velR03dt5k30.csv', names=['bm'])
r09dt5k30 = pd.read_csv('data/velR09dt5k30.csv', names=['bm'])

r03dt2k30ac = pd.read_csv('data/acBmR03dt2k30.csv', names=['bm'])
r03dt2k30def = pd.read_csv('data/defBmR03dt2k30.csv', names=['bm'])
r09dt2k30ac = pd.read_csv('data/acBmR09dt2k30.csv', names=['bm'])
r09dt2k30def = pd.read_csv('data/defBmR09dt2k30.csv', names=['bm'])
r03dt2k30 = pd.read_csv('data/velR03dt2k30.csv', names=['bm'])
r09dt2k30 = pd.read_csv('data/velR09dt2k30.csv', names=['bm'])

r03dt1k30ac = pd.read_csv('data/acBmR03dt1k30.csv', names=['bm'])
r03dt1k30def = pd.read_csv('data/defBmR03dt1k30.csv', names=['bm'])
r09dt1k30ac = pd.read_csv('data/acBmR09dt1k30.csv', names=['bm'])
r09dt1k30def = pd.read_csv('data/defBmR09dt1k30.csv', names=['bm'])
r03dt1k30 = pd.read_csv('data/velR03dt1k30.csv', names=['bm'])
r09dt1k30 = pd.read_csv('data/velR09dt1k30.csv', names=['bm'])

r03dt05k30ac = pd.read_csv('data/acBmR03dt0.5k30.csv', names=['bm'])
r03dt05k30def = pd.read_csv('data/defBmR03dt0.5k30.csv', names=['bm'])
r09dt05k30ac = pd.read_csv('data/acBmR09dt0.5k30.csv', names=['bm'])
r09dt05k30def = pd.read_csv('data/defBmR09dt0.5k30.csv', names=['bm'])
r03dt05k30 = pd.read_csv('data/velR03dt0.5k30.csv', names=['bm'])
r09dt05k30 = pd.read_csv('data/velR09dt0.5k30.csv', names=['bm'])

r095dt5k300ac = pd.read_csv('data/acBmR095dt5k300T1.csv', names=['bm'])
r095dt5k300def = pd.read_csv('data/defBmR095dt5k300T1.csv', names=['bm'])
r095dt2k300ac = pd.read_csv('data/acBmR095dt2k300T1.csv', names=['bm'])
r095dt2k300def = pd.read_csv('data/defBmR095dt2k300T1.csv', names=['bm'])
r095dt1k300ac = pd.read_csv('data/acBmR095dt1k300T1.csv', names=['bm'])
r095dt1k300def = pd.read_csv('data/defBmR095dt1k300T1.csv', names=['bm'])

r095dt20k300 = pd.read_csv('data/velR095dt20k300.csv', names=['spd'])
r095dt15k300 = pd.read_csv('data/velR095dt15k300.csv', names=['spd'])
r095dt14k300 = pd.read_csv('data/velR095dt14k300.csv', names=['spd'])
r095dt12k300 = pd.read_csv('data/velR095dt12k300.csv', names=['spd'])
r095dt11k300 = pd.read_csv('data/velR095dt11k300.csv', names=['spd'])
r095dt10k300 = pd.read_csv('data/velR095dt10k300.csv', names=['spd'])
r095dt7k300 = pd.read_csv('data/velR095dt7k300.csv', names=['spd'])
r095dt5k300 = pd.read_csv('data/velR095dt5k300.csv', names=['spd'])
r095dt2k300 = pd.read_csv('data/velR095dt2k300.csv', names=['spd'])
r095dt1k300 = pd.read_csv('data/velR095dt1k300.csv', names=['spd'])
r095dt05k300 = pd.read_csv('data/velR095dt05k300.csv', names=['spd'])

r03dt2k3ac = pd.read_csv('data/acBmR03dt2k3.csv', names=['bm'])
r03dt2k3def = pd.read_csv('data/defBmR03dt2k3.csv', names=['bm'])
r09dt2k3ac = pd.read_csv('data/acBmR09dt2k3.csv', names=['bm'])
r09dt2k3def = pd.read_csv('data/defBmR09dt2k3.csv', names=['bm'])

r03k30vel = np.array([r03dt05k30.mean(), r03dt1k30.mean(), r03dt2k30.mean(), r03dt5k30.mean()]); r03k30vel = r03k30vel.flatten()
r03k30std = np.array([r03dt05k30.std(), r03dt1k30.std(), r03dt2k30.std(), r03dt5k30.std()]); r03k30std = r03k30std.flatten()
r09k30vel = np.array([r09dt05k30.mean(), r09dt1k30.mean(), r09dt2k30.mean(), r09dt5k30.mean()]); r09k30vel = r09k30vel.flatten()
r09k30std = np.array([r09dt05k30.std(), r09dt1k30.std(), r09dt2k30.std(), r09dt5k30.std()]); r09k30std = r09k30std.flatten()
r095k300vel = np.array([r095dt20k300.mean(), r095dt15k300.mean(), r095dt14k300.mean(), r095dt12k300.mean(), r095dt11k300.mean(), r095dt10k300.mean(), r095dt7k300.mean(), r095dt5k300.mean(), r095dt2k300.mean(), r095dt1k300.mean(), r095dt05k300.mean()]); r095k300vel = r095k300vel.flatten()
r095k300std = np.array([r095dt20k300.std(), r095dt15k300.std(), r095dt14k300.std(), r095dt12k300.std(), r095dt11k300.std(), r095dt10k300.std(), r095dt7k300.std(), r095dt5k300.std(), r095dt2k300.std(), r095dt1k300.std(), r095dt05k300.std()]); r095k300std = r095k300std.flatten()

r03k30tym = pd.read_csv('data/simul_tym_R03k30.csv', names=['dt','tym'])
r09k30tym = pd.read_csv('data/simul_tym_R09k30.csv', names=['dt','tym'])
r095k300tym = pd.read_csv('data/simul_tym_R095k300.csv', names=['dt','tym'])

tym = np.linspace(0,0.3,31); tym2 = np.linspace(0,0.3,3); dt = np.array([0.5e-7, 1.0e-7, 2.0e-7, 5.0e-7])
tym3 = np.linspace(0,1.0,101); tym4 = np.linspace(0,1.0,10); dt2 = np.array([0.5e-7, 1.0e-7, 2.0e-7, 5.0e-7, 7.0e-7, 10.0e-7, 11.0e-7, 12.0e-7, 14.0e-7, 15.0e-7, 20.0e-7])

# %% [markdown]
# ### Changing k and R keeping $\Delta t$ constant

# %%
fig, ax = plt.subplots(1,4, figsize=(16,4))

ax[0].plot(tym, r03dt2ac['bm'], marker='o', markerfacecolor='salmon', color='green', label='Active')
ax[0].set_title('k = 300 | R = 0.3 | $\Delta t = 2.0e-7$'); ax[0].legend()
ax[0].annotate('*recorded NaN', xy=(0.1,12.5))
ax[1].plot(tym, r03dt2def['bm'], marker='o', markerfacecolor='salmon', color='blue', label='Defective')
ax[1].legend(); ax[1].annotate('*recorded NaN', xy=(0.1,135))
ax[2].plot(tym, r09dt2ac['bm'], marker='o', markerfacecolor='salmon', color='green', label='Active')
ax[2].set_title('k = 300 | R = 0.9 | $\Delta t = 2.0e-7$')
ax[3].plot(tym, r09dt2def['bm'], marker='o', markerfacecolor='salmon', color='blue', label='Defective')

fig.text(0.5,0.04,'Time(sec.)', ha='center')
ax[0].set_ylabel('Binding motors')
plt.show()

# %%
fig, ax = plt.subplots(1,4, figsize=(16,4))

ax[0].plot(tym, r03dt2k30ac['bm'], marker='o', markerfacecolor='salmon', color='green', label='Active')
ax[0].set_title('k = 30 | R = 0.3 | $\Delta t = 2.0e-7$'); ax[0].legend()
ax[1].plot(tym, r03dt2k30def['bm'], marker='o', markerfacecolor='salmon', color='blue', label='Defective')
ax[1].legend()
ax[2].plot(tym, r09dt2k30ac['bm'], marker='o', markerfacecolor='salmon', color='green', label='Active')
ax[2].set_title('k = 30 | R = 0.9 | $\Delta t = 2.0e-7$')
ax[3].plot(tym, r09dt2k30def['bm'], marker='o', markerfacecolor='salmon', color='blue', label='Defective')

fig.text(0.5,0.04,'Time(sec.)', ha='center')
ax[0].set_ylabel('Binding motors')
plt.show()

# %%
fig, ax = plt.subplots(1,4, figsize=(16,4))

ax[0].plot(tym, r03dt2k3ac['bm'], marker='o', markerfacecolor='salmon', color='green', label='Active')
ax[0].set_title('k = 3 | R = 0.3 | $\Delta t = 2.0e-7$'); ax[0].legend()
ax[1].plot(tym, r03dt2k3def['bm'], marker='o', markerfacecolor='salmon', color='blue', label='Defective')
ax[1].legend()
ax[2].plot(tym, r09dt2k3ac['bm'], marker='o', markerfacecolor='salmon', color='green', label='Active')
ax[2].set_title('k = 3 | R = 0.9 | $\Delta t = 2.0e-7$')
ax[3].plot(tym, r09dt2k3def['bm'], marker='o', markerfacecolor='salmon', color='blue', label='Defective')

fig.text(0.5,0.04,'Time(sec.)', ha='center')
ax[0].set_ylabel('Binding motors')
plt.show()

# %% [markdown]
# ### Changing $\Delta t$ and R keeping k constant

# %%
fig, ax = plt.subplots(1,5, figsize=(20,3))
plt.subplots_adjust(wspace=0.35)

ax[0].plot(tym, r03dt5k30ac['bm'], marker='o', markerfacecolor='salmon', color='green', label='Active')
ax[0].set_title('k = 30 | R = 0.3 | $\Delta t = 5.0e-7$'); ax[0].legend()
ax[1].plot(tym, r03dt5k30def['bm'], marker='o', markerfacecolor='salmon', color='blue', label='Defective')
ax[1].legend()
ax[2].plot(tym, r09dt5k30ac['bm'], marker='o', markerfacecolor='salmon', color='green', label='Active')
ax[2].set_title('k = 30 | R = 0.9 | $\Delta t = 5.0e-7$')
ax[3].plot(tym, r09dt5k30def['bm'], marker='o', markerfacecolor='salmon', color='blue', label='Defective')
ax[4].plot(tym2, r09dt5k30, marker='o', markerfacecolor='salmon', color='red', label='R = 0.9')
ax[4].plot(tym2, r03dt5k30, marker='o', markerfacecolor='salmon', color='magenta', label='R = 0.3')
ax[4].set_ylabel('Speed ($\mu m/sec.$)'); ax[4].set_title('Instantaneous speed'); ax[4].legend()

fig.text(0.5,0.001,'Time(sec.)', ha='center')
ax[0].set_ylabel('Binding motors')
plt.show()

# %%
fig, ax = plt.subplots(1,5, figsize=(20,3))
plt.subplots_adjust(wspace=0.35)

ax[0].plot(tym, r03dt2k30ac['bm'], marker='o', markerfacecolor='salmon', color='green', label='Active')
ax[0].set_title('k = 30 | R = 0.3 | $\Delta t = 2.0e-7$'); ax[0].legend()
ax[1].plot(tym, r03dt2k30def['bm'], marker='o', markerfacecolor='salmon', color='blue', label='Defective')
ax[1].legend()
ax[2].plot(tym, r09dt2k30ac['bm'], marker='o', markerfacecolor='salmon', color='green', label='Active')
ax[2].set_title('k = 30 | R = 0.9 | $\Delta t = 2.0e-7$')
ax[3].plot(tym, r09dt2k30def['bm'], marker='o', markerfacecolor='salmon', color='blue', label='Defective')
ax[4].plot(tym2, r09dt2k30, marker='o', markerfacecolor='salmon', color='red', label='R = 0.9')
ax[4].plot(tym2, r03dt2k30, marker='o', markerfacecolor='salmon', color='magenta', label='R = 0.3')
ax[4].set_ylabel('Speed ($\mu m/sec.$)'); ax[4].set_title('Instantaneous speed'); ax[4].legend()

fig.text(0.5,0.001,'Time(sec.)', ha='center')
ax[0].set_ylabel('Binding motors')
plt.show()

# %%
fig, ax = plt.subplots(1,5, figsize=(20,3))
plt.subplots_adjust(wspace=0.35)

ax[0].plot(tym, r03dt1k30ac['bm'], marker='o', markerfacecolor='salmon', color='green', label='Active')
ax[0].set_title('k = 30 | R = 0.3 | $\Delta t = 1.0e-7$'); ax[0].legend()
ax[1].plot(tym, r03dt1k30def['bm'], marker='o', markerfacecolor='salmon', color='blue', label='Defective')
ax[1].legend()
ax[2].plot(tym, r09dt1k30ac['bm'], marker='o', markerfacecolor='salmon', color='green', label='Active')
ax[2].set_title('k = 30 | R = 0.9 | $\Delta t = 1.0e-7$')
ax[3].plot(tym, r09dt1k30def['bm'], marker='o', markerfacecolor='salmon', color='blue', label='Defective')
ax[4].plot(tym2, r09dt1k30, marker='o', markerfacecolor='salmon', color='red', label='R = 0.9')
ax[4].plot(tym2, r03dt1k30, marker='o', markerfacecolor='salmon', color='magenta', label='R = 0.3')
ax[4].set_ylabel('Speed ($\mu m/sec.$)'); ax[4].set_title('Instantaneous speed'); ax[4].legend()

fig.text(0.5,0.001,'Time(sec.)', ha='center')
ax[0].set_ylabel('Binding motors')
plt.show()

# %%
fig, ax = plt.subplots(1,5, figsize=(20,3))
plt.subplots_adjust(wspace=0.35)

ax[0].plot(tym, r03dt05k30ac['bm'], marker='o', markerfacecolor='salmon', color='green', label='Active')
ax[0].set_title('k = 30 | R = 0.3 | $\Delta t = 0.5e-7$'); ax[0].legend()
ax[1].plot(tym, r03dt05k30def['bm'], marker='o', markerfacecolor='salmon', color='blue', label='Defective')
ax[1].legend()
ax[2].plot(tym, r09dt05k30ac['bm'], marker='o', markerfacecolor='salmon', color='green', label='Active')
ax[2].set_title('k = 30 | R = 0.9 | $\Delta t = 0.5e-7$')
ax[3].plot(tym, r09dt05k30def['bm'], marker='o', markerfacecolor='salmon', color='blue', label='Defective')
ax[4].plot(tym2, r09dt05k30, marker='o', markerfacecolor='salmon', color='red', label='R = 0.9')
ax[4].plot(tym2, r03dt05k30, marker='o', markerfacecolor='salmon', color='magenta', label='R = 0.3')
ax[4].set_ylabel('Speed ($\mu m/sec.$)'); ax[4].set_title('Instantaneous speed'); ax[4].legend()

fig.text(0.5,0.001,'Time(sec.)', ha='center')
ax[0].set_ylabel('Binding motors')
plt.show()

# %% [markdown]
# ### Changing $\Delta t$ keeping R constant

# %%
fig, ax = plt.subplots(1,3, figsize=(12,3))
plt.subplots_adjust(wspace=0.35)

ax[0].errorbar(dt,r03k30vel, r03k30std, marker='o', markerfacecolor='salmon', color='magenta', capsize=3, label='R = 0.3')
ax[0].set_ylabel('Speed ($\mu m/sec.$)'); ax[0].set_title('R = 0.3')
ax[1].errorbar(dt,r09k30vel, r09k30std, marker='o', markerfacecolor='salmon', color='red', capsize=3, label='R = 0.9')
ax[1].set_xlabel('$\Delta t$'); ax[1].set_ylabel('Speed ($\mu m/sec.$)'); ax[1].set_title('R = 0.9')
ax[2].plot(r09k30tym['dt'],r09k30tym['tym'], marker='o', markerfacecolor='salmon', color='red',label='R = 0.9')
ax[2].plot(r03k30tym['dt'],r03k30tym['tym'], marker='o', markerfacecolor='salmon', color='magenta', label='R = 0.3')
ax[2].set_ylabel('Time (hrs)'); ax[2].set_title('Simulation duration'); ax[2].legend()
plt.show()

# %% [markdown]
# ### Force Dependent Without Nishizaka2000 Rate | Changing $\Delta t$, k = 300, R = 0.95, ATP = 2000, MD = 2000, T = 1 sec.

# %%
fig, ax = plt.subplots(1,3, figsize=(12,3))
plt.subplots_adjust(wspace=0.35)

ax[0].plot(tym3, r095dt5k300ac['bm'], marker='o', markerfacecolor='salmon', color='green', label='Active')
ax[0].set_title('k = 300 | R = 0.95 | $\Delta t = 5.0e-7$'); ax[0].legend()
ax[0].set_yticks(np.arange(0,41,10))
ax[1].plot(tym3, r095dt5k300def['bm'], marker='o', markerfacecolor='salmon', color='blue', label='Defective')
ax[1].legend()
ax[1].set_yticks(np.arange(0,41,10))
ax[2].plot(tym4, r095dt5k300, marker='o', markerfacecolor='salmon', color='red', label='R = 0.95')
ax[2].set_ylabel('Speed ($\mu m/sec.$)'); ax[2].set_title('Instantaneous speed'); ax[2].legend()
ax[2].set_yticks(np.arange(0,11,2))

fig.text(0.5,0.001,'Time(sec.)', ha='center')
ax[0].set_ylabel('Binding motors')
plt.show()

# %%
fig, ax = plt.subplots(1,3, figsize=(12,3))
plt.subplots_adjust(wspace=0.35)

ax[0].plot(tym3, r095dt2k300ac['bm'], marker='o', markerfacecolor='salmon', color='green', label='Active')
ax[0].set_title('k = 300 | R = 0.95 | $\Delta t = 2.0e-7$'); ax[0].legend()
ax[0].set_yticks(np.arange(0,41,10))
ax[1].plot(tym3, r095dt2k300def['bm'], marker='o', markerfacecolor='salmon', color='blue', label='Defective')
ax[1].legend()
ax[1].set_yticks(np.arange(0,41,10))
ax[2].plot(tym4, r095dt2k300, marker='o', markerfacecolor='salmon', color='red', label='R = 0.95')
ax[2].set_ylabel('Speed ($\mu m/sec.$)'); ax[2].set_title('Instantaneous speed'); ax[2].legend()
ax[2].set_yticks(np.arange(0,11,2))

fig.text(0.5,0.001,'Time(sec.)', ha='center')
ax[0].set_ylabel('Binding motors')
plt.show()

# %%
fig, ax = plt.subplots(1,3, figsize=(12,3))
plt.subplots_adjust(wspace=0.35)

ax[0].plot(tym3, r095dt1k300ac['bm'], marker='o', markerfacecolor='salmon', color='green', label='Active')
ax[0].set_title('k = 300 | R = 0.95 | $\Delta t = 1.0e-7$'); ax[0].legend()
ax[0].set_yticks(np.arange(0,41,10))
ax[1].plot(tym3, r095dt1k300def['bm'], marker='o', markerfacecolor='salmon', color='blue', label='Defective')
ax[1].set_yticks(np.arange(0,41,10))
ax[1].legend()
ax[2].plot(tym4, r095dt1k300, marker='o', markerfacecolor='salmon', color='red', label='R = 0.95')
ax[2].set_ylabel('Speed ($\mu m/sec.$)'); ax[2].set_title('Instantaneous speed'); ax[2].legend()
ax[2].set_yticks(np.arange(0,11,2))

fig.text(0.5,0.001,'Time(sec.)', ha='center')
ax[0].set_ylabel('Binding motors')
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(15,5))
plt.subplots_adjust(wspace=0.35)

bm = pd.read_csv('data/bm.csv', names=['ac','def'])

ax[0].errorbar(np.flip(dt2),r095k300vel, r095k300std, marker='o', markerfacecolor='salmon', color='magenta', capsize=3, label='R = 0.95')
ax[0].set_ylabel('Speed ($\mu m/sec.$)'); ax[0].set_title('R = 0.95')
ax[0].ticklabel_format(axis='x', style='sci', scilimits=(0,0))
ax[0].set_yticks(np.arange(0,13,2))
ax[0].plot(np.flip(dt2),bm['ac'])
ax[1].plot(r095k300tym['dt'],r095k300tym['tym'], marker='o', markerfacecolor='salmon', color='red',label='R = 0.95')
ax[1].set_ylabel('Time (hrs)'); ax[1].set_title('Simulation duration'); ax[1].legend()
ax[1].ticklabel_format(axis='x', style='sci', scilimits=(0,0))
ax[1].set_xlabel('$\Delta t$')
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(8,6))
plt.subplots_adjust(wspace=0.35)

plt.plot(r095k300tym['dt'],bm['ac'], marker='o', markerfacecolor='salmon', color='green', label='Active')
plt.plot(r095k300tym['dt'],bm['def'], marker='o', markerfacecolor='salmon', color='blue', label='Defective')
plt.ylabel('Binding motors'); plt.title('R = 0.95')
plt.ticklabel_format(axis='x', style='sci', scilimits=(0,0))
plt.yticks(np.arange(0,31,5))
plt.legend()

plt.show()

# %%
# !jupyter nbconvert k_dt_comparison.ipynb --no-input
# Out:
# [NbConvertApp] Converting notebook k_dt_comparison.ipynb to html
# [NbConvertApp] Writing 917918 bytes to k_dt_comparison.html

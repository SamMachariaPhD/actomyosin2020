# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
m1r08_lyf05 = pd.read_csv('data05/all_active5s133R05_label_life.csv')
m1r08_lyf06 = pd.read_csv('data06/all_active5s133R06_label_life.csv')
m1r08_lyf07 = pd.read_csv('data7/all_active5s133R07_label_life.csv')
m1r08_lyf08 = pd.read_csv('data08/all_active5s133R08_label_life.csv')
m1r08_lyf09 = pd.read_csv('data09/all_active5s133R09_label_life.csv')

m2r08_lyf05 = pd.read_csv('data05/all_inactive5s133R05_label_life.csv')
m2r08_lyf06 = pd.read_csv('data06/all_inactive5s133R06_label_life.csv')
m2r08_lyf07 = pd.read_csv('data7/all_inactive5s133R07_label_life.csv')
m2r08_lyf08 = pd.read_csv('data08/all_inactive5s133R08_label_life.csv')
m2r08_lyf09 = pd.read_csv('data09/all_inactive5s133R09_label_life.csv')

# %%
fig, ax = plt.subplots(2,3, sharex=False, sharey=False, figsize=(10,8))

#fig.add_subplot(231, frameon=False)
bins = np.arange(0.0,0.51,0.01)

ax[0,0].hist(0.01*m1r08_lyf05['life'], bins=bins, color = 'magenta', hatch='/', ec='black', alpha=1, label='Active')
ax[0,0].set_xticks(np.arange(0.0,0.51,0.1))
ax[0,0].set_yticks(np.arange(0,15001,2500))
ax[0,0].tick_params(labelsize=14)
#ax[0,0].set_xlabel('Lifetime (sec)', fontsize=16)
#ax[0,0].set_ylabel('Number of occurrences', fontsize=16)
ax[0,0].spines['top'].set_visible(False)
ax[0,0].spines['right'].set_visible(False)
ax[0,0].spines['bottom'].set_bounds(0,0.5)
#ax[0,0].spines['left'].set_bounds(0,12500)
#ax[0,0].legend(loc='upper left')
mlyf = round(np.mean(0.01*m1r08_lyf05['life']), 2)
ax[0,0].set_title('R = 0.5 | $\mu$ = %s'%mlyf, fontsize=16)
#===============================================================
#fig.add_subplot(232, frameon=False)
bins = np.arange(0.0,0.341,0.01)

ax[0,1].hist(0.01*m1r08_lyf06['life'], bins=bins, color = 'grey', hatch='/', ec='black', alpha=1, label='Active')
ax[0,1].set_xticks(np.arange(0.0,0.341,0.08))
ax[0,1].set_yticks(np.arange(0,15001,2500))
ax[0,1].tick_params(labelsize=14, labelleft=False)
#ax[0,1].set_xlabel('Lifetime (sec)', fontsize=16)
#ax[0,1].set_ylabel('Number of occurrences', fontsize=16)
ax[0,1].spines['top'].set_visible(False)
ax[0,1].spines['right'].set_visible(False)
ax[0,1].spines['bottom'].set_bounds(0,0.32)
#ax[0,1].spines['left'].set_bounds(0,12500)
#ax[0,1].legend(loc='upper left')
mlyf = round(np.mean(0.01*m1r08_lyf06['life']), 2)
ax[0,1].set_title('R = 0.6 | $\mu$ = %s'%mlyf, fontsize=16)
#===============================================================
bins = np.arange(0.0,0.22,0.01)

ax[0,2].hist(0.01*m1r08_lyf07['life'], bins=bins, color = 'blue', hatch='/', ec='black', alpha=1, label='Active')
ax[0,2].set_xticks(np.arange(0.0,0.22,0.06))
ax[0,2].set_yticks(np.arange(0,15001,2500))
ax[0,2].tick_params(labelsize=14, labelleft=False)
#ax[0,2].set_xlabel('Lifetime (sec)', fontsize=16)
#ax[0,2].set_ylabel('Number of occurrences', fontsize=16)
ax[0,2].spines['top'].set_visible(False)
ax[0,2].spines['right'].set_visible(False)
ax[0,2].spines['bottom'].set_bounds(0,0.2)
#ax[0,2].spines['left'].set_bounds(0,12500)
#ax[0,2].legend(loc='upper left')
mlyf = round(np.mean(0.01*m1r08_lyf07['life']), 2)
ax[0,2].set_title('R = 0.7 | $\mu$ = %s'%mlyf, fontsize=16)
#===============================================================
bins = np.arange(0.0,0.081,0.01)

ax[1,0].hist(0.01*m1r08_lyf08['life'], bins=bins, color = 'red', hatch='/', ec='black', alpha=1, label='Active')
ax[1,0].set_xticks(np.arange(0.0,0.081,0.02))
ax[1,0].set_yticks(np.arange(0,15001,2500))
ax[1,0].tick_params(labelsize=14)
#ax[1,0].set_xlabel('Lifetime (sec)', fontsize=16)
#ax[1,0].set_ylabel('Number of occurrences', fontsize=16)
ax[1,0].spines['top'].set_visible(False)
ax[1,0].spines['right'].set_visible(False)
ax[1,0].spines['bottom'].set_bounds(0,0.08)
#ax[1,0].spines['left'].set_bounds(0,15000)
#ax[1,0].legend(loc='upper left')
mlyf = round(np.mean(0.01*m1r08_lyf08['life']), 2)
ax[1,0].set_title('R = 0.8 | $\mu$ = %s'%mlyf, fontsize=16)
#===============================================================
bins = np.arange(0.0,0.041,0.01)

ax[1,1].hist(0.01*m1r08_lyf09['life'], bins=bins, color = 'green', hatch='/', ec='black', alpha=1, label='Active')
ax[1,1].set_xticks(np.arange(0.0,0.041,0.01))
ax[1,1].set_yticks(np.arange(0,15001,2500))
ax[1,1].tick_params(labelsize=14, labelleft=False)
#ax[1,1].set_xlabel('Lifetime (sec)', fontsize=16)
#ax[1,1].set_ylabel('Number of occurrences', fontsize=16)
ax[1,1].spines['top'].set_visible(False)
ax[1,1].spines['right'].set_visible(False)
ax[1,1].spines['bottom'].set_bounds(0,0.04)
#ax[1,1].legend(loc='upper left')
mlyf = round(np.mean(0.01*m1r08_lyf09['life']), 2)
ax[1,1].set_title('R = 0.9 | $\mu$ = %s'%mlyf, fontsize=16)
#===============================================================


bins = np.arange(0.0,0.51,0.01)

ax[1,2].hist(0.01*m1r08_lyf05['life'], bins=bins, color = 'magenta', hatch='/', ec='black', label='Active')

ax[1,2].tick_params(labelsize=14, labelleft=False)
ax[1,2].spines['top'].set_visible(False)
ax[1,2].spines['right'].set_visible(False)
ax[1,2].spines['bottom'].set_bounds(0,0.5)
#ax[0,0].set_title('R = 0.5 | $\mu$ = %s'%mlyf, fontsize=16)
#===============================================================

ax[1,2].hist(0.01*m1r08_lyf06['life'], bins=bins, color = 'grey', hatch='/', ec='black', label='Active')

#===============================================================

ax[1,2].hist(0.01*m1r08_lyf07['life'], bins=bins, color = 'blue', hatch='/', ec='black', label='Active')

#===============================================================

ax[1,2].hist(0.01*m1r08_lyf08['life'], bins=bins, color = 'red', hatch='/', ec='black', label='Active')

#===============================================================

ax[1,2].hist(0.01*m1r08_lyf09['life'], bins=bins, color = 'green', hatch='/', ec='black', label='Active')

ax[1,2].set_xticks(np.arange(0.0,0.51,0.1))
ax[1,2].set_yticks(np.arange(0,15001,2500))

ax[1,2].set_title('R = 0.5 - 0.9', fontsize=16)

fig.text(0.5,0.04, 'Lifetime (sec)', fontsize=16, va='center', ha='center')
fig.text(0.03,0.5, 'Occurrences', fontsize=16, va='center', ha='center', rotation='vertical')

plt.subplots_adjust(hspace=0.3)

#plt.savefig('figLife/R0509ActiveLife.svg', fmt='.svg', dpi=1200, bbox_inches='tight')
#plt.savefig('figLife/R0509ActiveLife.png', fmt='.png', dpi=1200, bbox_inches='tight')

plt.show()

# %%
fig, ax = plt.subplots(2,3, sharex=False, sharey=False, figsize=(10,8))

#fig.add_subplot(231, frameon=False)
bins = np.arange(0.0,4.1,0.01)

ax[0,0].hist(0.01*m2r08_lyf05['life'], bins=bins, color = 'magenta', hatch='\\', ec='magenta', alpha=1, label='Active')
ax[0,0].set_xticks(np.arange(0.0,4.1,0.8))
ax[0,0].set_yticks(np.arange(0,1801,300))
ax[0,0].tick_params(labelsize=14)
#ax[0,0].set_xlabel('Lifetime (sec)', fontsize=16)
#ax[0,0].set_ylabel('Number of occurrences', fontsize=16)
ax[0,0].spines['top'].set_visible(False)
ax[0,0].spines['right'].set_visible(False)
ax[0,0].spines['bottom'].set_bounds(0,4.0)
#ax[0,0].spines['left'].set_bounds(0,12500)
#ax[0,0].legend(loc='upper left')
mlyf = round(np.mean(0.01*m2r08_lyf05['life']), 2)
ax[0,0].set_title('R = 0.5 | $\mu$ = %s'%mlyf, fontsize=16)
#===============================================================
#fig.add_subplot(232, frameon=False)
bins = np.arange(0.0,2.1,0.01)

ax[0,1].hist(0.01*m2r08_lyf06['life'], bins=bins, color = 'grey', hatch='\\', ec='grey', alpha=1, label='Active')
ax[0,1].set_xticks(np.arange(0.0,2.1,0.4))
ax[0,1].set_yticks(np.arange(0,1801,300))
ax[0,1].tick_params(labelsize=14, labelleft=False)
#ax[0,1].set_xlabel('Lifetime (sec)', fontsize=16)
#ax[0,1].set_ylabel('Number of occurrences', fontsize=16)
ax[0,1].spines['top'].set_visible(False)
ax[0,1].spines['right'].set_visible(False)
ax[0,1].spines['bottom'].set_bounds(0,2.0)
#ax[0,1].spines['left'].set_bounds(0,12500)
#ax[0,1].legend(loc='upper left')
mlyf = round(np.mean(0.01*m2r08_lyf06['life']), 2)
ax[0,1].set_title('R = 0.6 | $\mu$ = %s'%mlyf, fontsize=16)
#===============================================================
bins = np.arange(0.0,0.61,0.01)

ax[0,2].hist(0.01*m2r08_lyf07['life'], bins=bins, color = 'blue', hatch='\\', ec='black', alpha=1, label='Active')
ax[0,2].set_xticks(np.arange(0.0,0.61,0.1))
ax[0,2].set_yticks(np.arange(0,1801,300))
ax[0,2].tick_params(labelsize=14, labelleft=False)
#ax[0,2].set_xlabel('Lifetime (sec)', fontsize=16)
#ax[0,2].set_ylabel('Number of occurrences', fontsize=16)
ax[0,2].spines['top'].set_visible(False)
ax[0,2].spines['right'].set_visible(False)
ax[0,2].spines['bottom'].set_bounds(0,0.6)
#ax[0,2].spines['left'].set_bounds(0,12500)
#ax[0,2].legend(loc='upper left')
mlyf = round(np.mean(0.01*m2r08_lyf07['life']), 2)
ax[0,2].set_title('R = 0.7 | $\mu$ = %s'%mlyf, fontsize=16)
#===============================================================
bins = np.arange(0.0,0.281,0.01)

ax[1,0].hist(0.01*m2r08_lyf08['life'], bins=bins, color = 'red', hatch='\\', ec='black', alpha=1, label='Active')
ax[1,0].set_xticks(np.arange(0.0,0.281,0.07))
ax[1,0].set_yticks(np.arange(0,1801,300))
ax[1,0].tick_params(labelsize=14)
#ax[1,0].set_xlabel('Lifetime (sec)', fontsize=16)
#ax[1,0].set_ylabel('Number of occurrences', fontsize=16)
ax[1,0].spines['top'].set_visible(False)
ax[1,0].spines['right'].set_visible(False)
ax[1,0].spines['bottom'].set_bounds(0,0.28)
#ax[1,0].spines['left'].set_bounds(0,15000)
#ax[1,0].legend(loc='upper left')
mlyf = round(np.mean(0.01*m2r08_lyf08['life']), 2)
ax[1,0].set_title('R = 0.8 | $\mu$ = %s'%mlyf, fontsize=16)
#===============================================================
bins = np.arange(0.0,0.11,0.01)

ax[1,1].hist(0.01*m2r08_lyf09['life'], bins=bins, color = 'green', hatch='\\', ec='black', alpha=1, label='Active')
ax[1,1].set_xticks(np.arange(0.0,0.131,0.03))
ax[1,1].set_yticks(np.arange(0,1801,300))
ax[1,1].tick_params(labelsize=14, labelleft=False)
#ax[1,1].set_xlabel('Lifetime (sec)', fontsize=16)
#ax[1,1].set_ylabel('Number of occurrences', fontsize=16)
ax[1,1].spines['top'].set_visible(False)
ax[1,1].spines['right'].set_visible(False)
ax[1,1].spines['bottom'].set_bounds(0,0.12)
#ax[1,1].legend(loc='upper left')
mlyf = round(np.mean(0.01*m2r08_lyf09['life']), 2)
ax[1,1].set_title('R = 0.9 | $\mu$ = %s'%mlyf, fontsize=16)
#===============================================================


bins = np.arange(0.0,4.1,0.01)

ax[1,2].hist(0.01*m2r08_lyf05['life'], bins=bins, color = 'magenta', hatch='\\', ec='magenta', label='Active')

ax[1,2].tick_params(labelsize=14, labelleft=False)
ax[1,2].spines['top'].set_visible(False)
ax[1,2].spines['right'].set_visible(False)
ax[1,2].spines['bottom'].set_bounds(0,4.0)
#ax[0,0].set_title('R = 0.5 | $\mu$ = %s'%mlyf, fontsize=16)
#===============================================================

ax[1,2].hist(0.01*m2r08_lyf06['life'], bins=bins, color = 'grey', hatch='\\', ec='grey', label='Active')

#===============================================================

ax[1,2].hist(0.01*m2r08_lyf07['life'], bins=bins, color = 'blue', hatch='\\', ec='blue', label='Active')

#===============================================================

ax[1,2].hist(0.01*m2r08_lyf08['life'], bins=bins, color = 'red', hatch='\\', ec='red', label='Active')

#===============================================================

ax[1,2].hist(0.01*m2r08_lyf09['life'], bins=bins, color = 'green', hatch='\\', ec='green', label='Active')

ax[1,2].set_xticks(np.arange(0.0,4.1,0.8))
ax[1,2].set_yticks(np.arange(0,1801,300))

ax[1,2].set_title('R = 0.5 - 0.9', fontsize=16)

fig.text(0.5,0.04, 'Lifetime (sec)', fontsize=16, va='center', ha='center')
fig.text(0.03,0.5, 'Occurrences', fontsize=16, va='center', ha='center', rotation='vertical')

plt.subplots_adjust(hspace=0.3)

#plt.savefig('figLife/R0509InactiveLife.svg', fmt='.svg', dpi=1200, bbox_inches='tight')
#plt.savefig('figLife/R0509InactiveLife.png', fmt='.png', dpi=1200, bbox_inches='tight')

plt.show()

# %%
m1r08_lyf05_ = m1r08_lyf05.sort_values(['Ts'], ascending=[True])
m1r08_lyf06_ = m1r08_lyf06.sort_values(['Ts'], ascending=[True])
m1r08_lyf07_ = m1r08_lyf07.sort_values(['Ts'], ascending=[True])
m1r08_lyf08_ = m1r08_lyf08.sort_values(['Ts'], ascending=[True])
m1r08_lyf09_ = m1r08_lyf09.sort_values(['Ts'], ascending=[True])

m2r08_lyf05_ = m2r08_lyf05.sort_values(['Ts'], ascending=[True])
m2r08_lyf06_ = m2r08_lyf06.sort_values(['Ts'], ascending=[True])
m2r08_lyf07_ = m2r08_lyf07.sort_values(['Ts'], ascending=[True])
m2r08_lyf08_ = m2r08_lyf08.sort_values(['Ts'], ascending=[True])
m2r08_lyf09_ = m2r08_lyf09.sort_values(['Ts'], ascending=[True])

# %%
plt.figure(figsize=(15,7))

plt.subplot(2,5,1)
plt.plot(m1r08_lyf05_['Ts'],0.01*m1r08_lyf05_['life'], color='green', linestyle='-', alpha=0.7)
plt.title('R = 0.5')
plt.xticks(np.arange(0,501,100))
plt.yticks(np.arange(0.0,1.751,0.25))
plt.ylabel('Lifetime', fontsize=15)
plt.subplot(2,5,2)
plt.plot(m1r08_lyf06_['Ts'],0.01*m1r08_lyf06_['life'], color='green', linestyle='-', alpha=0.7)
plt.title('R = 0.6')
plt.xticks(np.arange(0,501,100))
plt.yticks(np.arange(0.0,1.751,0.25))
plt.subplot(2,5,3)
plt.plot(m1r08_lyf07_['Ts'],0.01*m1r08_lyf07_['life'], color='green', linestyle='-', alpha=0.7)
plt.title('R = 0.7')
plt.xticks(np.arange(0,501,100))
plt.yticks(np.arange(0.0,1.751,0.25))
plt.subplot(2,5,4)
plt.plot(m1r08_lyf08_['Ts'],0.01*m1r08_lyf08_['life'], color='green', linestyle='-', alpha=0.7)
plt.title('R = 0.8')
plt.xticks(np.arange(0,501,100))
plt.yticks(np.arange(0.0,1.751,0.25))
plt.subplot(2,5,5)
plt.plot(m1r08_lyf09_['Ts'],0.01*m1r08_lyf09_['life'], color='green', linestyle='-', alpha=0.7)
plt.title('R = 0.9')
plt.xticks(np.arange(0,501,100))
plt.yticks(np.arange(0.0,1.751,0.25))

plt.subplot(2,5,6)
plt.plot(m2r08_lyf05_['Ts'],0.01*m2r08_lyf05_['life'], color='blue', linestyle='-', alpha=0.7)
plt.title('R = 0.5')
plt.xticks(np.arange(0,501,100))
plt.yticks(np.arange(0.0,3.251,0.5))
plt.ylabel('Lifetime', fontsize=15)
plt.subplot(2,5,7)
plt.plot(m2r08_lyf06_['Ts'],0.01*m2r08_lyf06_['life'], color='blue', linestyle='-', alpha=0.7)
plt.title('R = 0.6')
plt.xticks(np.arange(0,501,100))
plt.yticks(np.arange(0.0,1.751,0.25))
plt.subplot(2,5,8)
plt.plot(m2r08_lyf07_['Ts'],0.01*m2r08_lyf07_['life'], color='blue', linestyle='-', alpha=0.7)
plt.title('R = 0.7')
plt.xticks(np.arange(0,501,100))
plt.yticks(np.arange(0.0,1.751,0.25))
plt.xlabel('Timestep', fontsize=15)
plt.subplot(2,5,9)
plt.plot(m2r08_lyf08_['Ts'],0.01*m2r08_lyf08_['life'], color='blue', linestyle='-', alpha=0.7)
plt.title('R = 0.8')
plt.xticks(np.arange(0,501,100))
plt.yticks(np.arange(0.0,1.751,0.25))
plt.subplot(2,5,10)
plt.plot(m2r08_lyf09_['Ts'],0.01*m2r08_lyf09_['life'], color='blue', linestyle='-', alpha=0.7)
plt.title('R = 0.9')
plt.xticks(np.arange(0,501,100))
plt.yticks(np.arange(0.0,1.751,0.25))

plt.subplots_adjust(hspace=0.3)
plt.subplots_adjust(wspace=0.3)

#plt.savefig('figLife/R0509LifeBuildup.svg', fmt='.svg', dpi=1200, bbox_inches='tight')
#plt.savefig('figLife/R0509LifeBuildup.png', fmt='.png', dpi=1200, bbox_inches='tight')

plt.show()

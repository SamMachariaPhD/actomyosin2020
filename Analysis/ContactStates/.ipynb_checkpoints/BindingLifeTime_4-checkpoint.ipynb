# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Ts = 501
segments = 12 # beads = 13

# %%
fil = []

for i in range(Ts):
    fil_ = pd.read_csv('data5/Filament_5s133R0.8Ts'+str(i)+'.csv', names=['x','y','z'], skiprows=1) 
    fil.append(fil_)

# %%
m1r08_Aglf = pd.read_csv('data6/active5s133R08_aggressive.csv')
m2r08_Aglf = pd.read_csv('data6/inactive5s133R08_aggressive.csv')

# %%
m1r08_Ag_upd = pd.read_csv('data6/all_active5s133R08_label_life.csv')
m2r08_Ag_upd = pd.read_csv('data6/all_inactive5s133R08_label_life.csv')

# %%
round(m1r08_Ag_upd['life'].mean(), 0)
# Out:
# 0.0

# %%
round(m2r08_Ag_upd['life'].mean(), 0)
# Out:
# 4.0

# %%
m1r08_Ag_upd = m1r08_Ag_upd[m1r08_Ag_upd.life >= 0] # only defective aggressive motors == 1
m2r08_Ag_upd = m2r08_Ag_upd[m2r08_Ag_upd.life >= 4]

m1r08_Ag_upd = m1r08_Ag_upd.sort_values(['Ts'], ascending=[True])
m2r08_Ag_upd = m2r08_Ag_upd.sort_values(['Ts'], ascending=[True])

m1r08_Ag_u = m1r08_Ag_upd.set_index('Ts')
m2r08_Ag_u = m2r08_Ag_upd.set_index('Ts')

# %%
Ag_in_ts_ = []

try:
    for i in range(501):
        Ag_in_ts_.append(len(m2r08_Ag_u.loc[i]))
except Exception as e:
    print(e)

Ag_in_ts = np.array(Ag_in_ts_)
print('%s: Timestep with the greates no. of defective aggressive motors'%(np.max(Ag_in_ts)))
# Out:
# 19
# 44: Timestep with the greates no. of defective aggressive motors

# %%
plt.style.use('ggplot')

#idx = 19
i=0
unplottedA = []
unplottedI = []

while i < Ts:
    for idx in range(i,i+1):
        fig, ax = plt.subplots(figsize=(10,8))

        ax.plot(fil[idx]['x'],fil[idx]['y'], marker='o', color='red', markerfacecolor='None', linestyle='-', linewidth=2, label='Actin')
        ax.scatter(fil[idx]['x'][0],fil[idx]['y'][0], marker='D', color='black', label='Leading tip')
        try:
            ax.scatter(m1r08_Ag_u.loc[idx]['x'], m1r08_Ag_u.loc[idx]['y'], marker='o', color='green', label='Active')
        except Exception as e:
            unplottedA.append(e)
        try:
            ax.scatter(m2r08_Ag_u.loc[idx]['x'], m2r08_Ag_u.loc[idx]['y'], marker='o', color='blue', label='Defective') # aggressive
        except Exception as e:
            unplottedI.append(e)
        ax.set_xticks(np.arange(0.4,6.1,0.4))
        ax.set_yticks(np.arange(-2.0,2.4,0.4))
        
        ax.minorticks_on()
        ax.tick_params('both', direction='in', top=True, right=True, length=9, width=0.5, which='major') #
        ax.tick_params('both', direction='in', top=True, right=True, length=4, width=0.4, which='minor') #

        ax.set_xlabel('X ($\mu m$)', fontsize=15) #
        ax.set_ylabel('Y ($\mu m$)', fontsize=15) #
        
        ax.text(0.95,-0.06,'@NittaLab', color='grey', horizontalalignment ='center', verticalalignment='center', transform=ax.transAxes)
        ax.set_aspect('equal') #
        ax.legend(loc = 'upper left')

        if i <10:
            ax.set_title('R = 0.8 | Def. life $\geq$ 0.04 sec | Act. life $\geq$ 0.00 sec | Ts: 00%s'%i, fontsize=16) # >= mean
            plt.savefig('figInAcAg/'+'00'+str(i)+'.png', fmt='.png', dpi=500, bbox_inches='tight')
        if i >9 and i <100:
            ax.set_title('R = 0.8 | Def. life $\geq$ 0.04 sec | Act. life $\geq$ 0.00 sec | Ts: 0%s'%i, fontsize=16) # >= mean
            plt.savefig('figInAcAg/'+'0'+str(i)+'.png', fmt='.png', dpi=500, bbox_inches='tight')
        if i >99 and i < Ts:
            ax.set_title('R = 0.8 | Def. life $\geq$ 0.04 sec | Act. life $\geq$ 0.00 sec | Ts: %s'%i, fontsize=16) # >= mean
            plt.savefig('figInAcAg/'+str(i)+'.png', fmt='.png', dpi=500, bbox_inches='tight')

        plt.close()
    i+=1

#plt.show()
plt.close()

# %%
import cv2
import time
import glob

fRate = 15
start = 0
dx = 50

for film in range(10):
    movieName = 'figInAcAg/Active002Defective003AggressiveTs'+str(start)+'_'+str(start+dx)+'.avi'

    frames = []
    images = glob.glob('figInAcAg/*.png')
    images = sorted(images, key=lambda x:x[-7:])
    images = images[start:start+dx]

    for i in images:
        frame = cv2.imread(i); print(i)
        H, W, layers = frame.shape
        size = (W,H)
        frames.append(frame)

    out = cv2.VideoWriter(movieName,cv2.VideoWriter_fourcc(*'DIVX'),fRate,size)

    for j in range(len(frames)):
        out.write(frames[j])
    out.release()
    start+=dx
    time.sleep(15)
# Out:
# figInAcAg/000.png
# figInAcAg/001.png
# figInAcAg/002.png
# figInAcAg/003.png
# figInAcAg/004.png
# figInAcAg/005.png
# figInAcAg/006.png
# figInAcAg/007.png
# figInAcAg/008.png
# figInAcAg/009.png
# figInAcAg/010.png
# figInAcAg/011.png
# figInAcAg/012.png
# figInAcAg/013.png
# figInAcAg/014.png
# figInAcAg/015.png
# figInAcAg/016.png
# figInAcAg/017.png
# figInAcAg/018.png
# figInAcAg/019.png
# figInAcAg/020.png
# figInAcAg/021.png
# figInAcAg/022.png
# figInAcAg/023.png
# figInAcAg/024.png
# figInAcAg/025.png
# figInAcAg/026.png
# figInAcAg/027.png
# figInAcAg/028.png
# figInAcAg/029.png
# figInAcAg/030.png
# figInAcAg/031.png
# figInAcAg/032.png
# figInAcAg/033.png
# figInAcAg/034.png
# figInAcAg/035.png
# figInAcAg/036.png
# figInAcAg/037.png
# figInAcAg/038.png
# figInAcAg/039.png
# figInAcAg/040.png
# figInAcAg/041.png
# figInAcAg/042.png
# figInAcAg/043.png
# figInAcAg/044.png
# figInAcAg/045.png
# figInAcAg/046.png
# figInAcAg/047.png
# figInAcAg/048.png
# figInAcAg/049.png
# figInAcAg/050.png
# figInAcAg/051.png
# figInAcAg/052.png
# figInAcAg/053.png
# figInAcAg/054.png
# figInAcAg/055.png
# figInAcAg/056.png
# figInAcAg/057.png
# figInAcAg/058.png
# figInAcAg/059.png
# figInAcAg/060.png
# figInAcAg/061.png
# figInAcAg/062.png
# figInAcAg/063.png
# figInAcAg/064.png
# figInAcAg/065.png
# figInAcAg/066.png
# figInAcAg/067.png
# figInAcAg/068.png
# figInAcAg/069.png
# figInAcAg/070.png
# figInAcAg/071.png
# figInAcAg/072.png
# figInAcAg/073.png
# figInAcAg/074.png
# figInAcAg/075.png
# figInAcAg/076.png
# figInAcAg/077.png
# figInAcAg/078.png
# figInAcAg/079.png
# figInAcAg/080.png
# figInAcAg/081.png
# figInAcAg/082.png
# figInAcAg/083.png
# figInAcAg/084.png
# figInAcAg/085.png
# figInAcAg/086.png
